# %% [markdown]
# # Machine Learning Code for Wine Quality Project

# %%
#load in pandas library for data manipulation and converstion of CSV data to dataframe
import pandas as pd

# %% [markdown]
# ## Connection to external database.  For the purposes of demonstrating the code, this portion is not fully active, but is included here to establish that once in production, the connection will be to an external database rather than reading from CSV files locally

# %%
#import library for connecting to external database
#import psycopg2

#connect to PostgreSQL database
#conn = psycopg2.connect(
#    host='localhost',
#    database='final_project_wine_db',
#    user='root',
#    password='WineDBProject2021#')

#sample_df = pd.read_sql_query('select * from winequality_training_data2', conn)

#going forward, this code will be improved and used in place of connecting to the csv file directly

# %% [markdown]
# ## Original CSV dataset was obtained from Kaggle.  For the purposes of this project, the dataset was reduced from its original size to fit the training portion of the program. No further modifications were made to this initial dataset

# %%
#load in CSV file and convert to dataframe
file_path = 'winequality_training_data2.csv'
wine_df = pd.read_csv(file_path)

#review file to ensure it loaded properly
wine_df.head()
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white            6.2             0.450         0.26             4.4
# 1  white            9.8             0.360         0.46            10.5
# 2  white            5.5             0.485         0.00             1.5
# 3  white            6.4             0.595         0.14             5.2
# 4  white            7.6             0.480         0.37             0.8
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.063                 63.0                 206.0   0.9940  3.27
# 1        NaN                  4.0                  83.0   0.9956  2.89
# 2      0.065                  8.0                 103.0   0.9940  3.63
# 3      0.058                 15.0                  97.0   0.9951  3.38
# 4      0.037                  4.0                 100.0   0.9902  3.03
#
#    sulphates  alcohol  quality
# 0       0.52      9.8        4
# 1       0.30     10.1        4
# 2       0.40      9.7        4
# 3       0.36      9.0        4
# 4       0.39     11.4        4

# %% [markdown]
# ## Clean up csv file using Python commands.  When project is fully in production, this portion of the data cleanup will actually be completed in the database portion of the project

# %%
#drop null rows
wine_df = wine_df.dropna()

#drop any null columns
wine_df = wine_df.dropna(axis='columns', how='all')

# %% [markdown]
# ## Import train_test_split model for testing purposes
# ## Create features to be used by model

# %%
# Import train_test_split
from sklearn.model_selection import train_test_split

#create features
X = wine_df.copy()
X = pd.get_dummies(X, columns=['type'])
X = X.drop(columns='quality')

#create target
y = wine_df['quality']

#split up the data
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y)

# %% [markdown]
# ## Multiple potential models were attempted in order to identify the one that provided the most accurate results and could produce the results in a way that fit with the plan for visualization and the ultimate goal of being able to predict wine quality based on certain categories.  Ultimately, RandomForestClassifier produced the most desirable results.

# %%
#import RandomForestClassifier to create training model
from sklearn.ensemble import RandomForestClassifier

# Create model
rf_model = RandomForestClassifier()
rf_model = rf_model.fit(X_train, y_train)

# %% [markdown]
# ## Determine the importance of features for inclusion in visualization and for use in future quality determinations/modifications.  Create output file of importances for use in data visualization

# %%
#determine importances
importances = rf_model.feature_importances_
sorted(zip(rf_model.feature_importances_, X.columns), reverse=True)
# Out:
# [(0.14548801289415617, 'alcohol'),
#  (0.1016945227847503, 'density'),
#  (0.09993460748657326, 'volatile acidity'),
#  (0.09531921150295203, 'chlorides'),
#  (0.08555543401125859, 'sulphates'),
#  (0.08235875208541321, 'fixed acidity'),
#  (0.07575659676258616, 'residual sugar'),
#  (0.07566880304841421, 'pH'),
#  (0.07557260072618985, 'free sulfur dioxide'),
#  (0.07335075675746167, 'citric acid'),
#  (0.06970456513129362, 'total sulfur dioxide'),
#  (0.011231023010660252, 'type_red'),
#  (0.008365113798290837, 'type_white')]

# %%
#convert importances to a dataframe
importances_df = pd.DataFrame(importances, columns=['Importance_Score'])

# %%
#save categories to an array
categories = X.columns

# %%
#insert categories column into dataframe
importances_df.insert(0,'Categories','')
importances_df['Categories'] = categories

# %%
#sort by importance score
mportances_df = importances_df.sort_values(by=['Importance_Score'], ascending=False)
importances_df.head()
# Out:
#          Categories  Importance_Score
# 0     fixed acidity          0.082359
# 1  volatile acidity          0.099935
# 2       citric acid          0.073351
# 3    residual sugar          0.075757
# 4         chlorides          0.095319

# %%
#export results for data visualization
importances_df.to_csv('importance_weights.csv', index=False)

# %% [markdown]
# ## Test model against dataset that does not have quality scores already calculated

# %%
#read in testing dataset and load into new dataframe
file_path = 'winequality-sample-set.csv'
test_wine_df = pd.read_csv(file_path)

# %%
#create sample set factors
X_sample_set = test_wine_df.copy()

#check sample set
X_sample_set.head()
# Out:
#   wine_id   type  fixed acidity  volatile acidity  citric acid  \
# 0   W-001  white            7.0              0.27         0.36
# 1   W-002  white            6.3              0.30         0.34
# 2   W-003  white            8.1              0.28         0.40
# 3   W-004  white            7.2              0.23         0.32
# 4   W-005  white            7.2              0.23         0.32
#
#    residual sugar  chlorides  free sulfur dioxide  total sulfur dioxide  \
# 0            20.7      0.045                   45                   170
# 1             1.6      0.049                   14                   132
# 2             6.9      0.050                   30                    97
# 3             8.5      0.058                   47                   186
# 4             8.5      0.058                   47                   186
#
#    density    pH  sulphates  alcohol
# 0   1.0010  3.00       0.45      8.8
# 1   0.9940  3.30       0.49      9.5
# 2   0.9951  3.26       0.44     10.1
# 3   0.9956  3.19       0.40      9.9
# 4   0.9956  3.19       0.40      9.9

# %%
#extract wine_id column for indentification later; not used in the model
y = X_sample_set['wine_id']

#drop column from sample set
X_sample_set = X_sample_set.drop(columns='wine_id')

# %%
#modify data to reflect structure of model
X_sample_set = pd.get_dummies(X_sample_set, columns=['type'])

# %%
#calculate predicted wine quality for sample set
predictions = rf_model.predict(X_sample_set)

# %%
#create final dataframe with calculated data
final_set = X_sample_set

#add column for calculated quality predictions
final_set['quality'] = predictions

#add wine_id column to final data set
final_set.insert(0, 'wine_id','')
final_set['wine_id'] = y

#show final set
final_set.head()
# Out:
#   wine_id  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0   W-001            7.0              0.27         0.36            20.7
# 1   W-002            6.3              0.30         0.34             1.6
# 2   W-003            8.1              0.28         0.40             6.9
# 3   W-004            7.2              0.23         0.32             8.5
# 4   W-005            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                   45                   170   1.0010  3.00
# 1      0.049                   14                   132   0.9940  3.30
# 2      0.050                   30                    97   0.9951  3.26
# 3      0.058                   47                   186   0.9956  3.19
# 4      0.058                   47                   186   0.9956  3.19
#
#    sulphates  alcohol  type_red   type_white  quality
# 0       0.45      8.8          0           1        3
# 1       0.49      9.5          0           1        4
# 2       0.44     10.1          0           1        5
# 3       0.40      9.9          0           1        8
# 4       0.40      9.9          0           1        8

# %%
final_set.to_csv('wine_outcome.csv', index=False)
